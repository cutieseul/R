# %%
BP <- read.csv("../../Data/프로젝트/220608_BP.csv")

# %%
library(dplyr)
# Out:
# Attaching package: ‘dplyr’
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union

# %%
arrange(BP,등급)
# Out:
#       나이 성별 키    몸무게 체지방률 이완기혈압 수축기혈압 악력 앞으로굽히기
# 1     25   M    165.0 55.80  15.7     77         126        36.4 16.3
# 2     42   M    169.2 65.40  19.3     63         110        43.5 16.0
# 3     45   F    159.0 63.10  30.9     93         144        34.1 19.0
# 4     26   M    179.9 71.50   9.7     64         135        59.6 17.8
# 5     59   F    155.9 62.70  30.2     76         143        36.8 29.1
# 6     50   F    159.8 57.10  24.4     63         103        30.8 24.4
# 7     28   F    159.5 51.54  24.5     82         123        37.2 23.0
# 8     31   M    177.5 79.50  23.0     90         148        51.2 18.4
# 9     32   M    178.0 84.50  21.2     68         130        52.3 16.2
# 10    25   F    161.8 57.70  21.7     74         115        29.3 26.6
# 11    28   M    180.1 82.10  15.0     83         147        52.6 18.8
# 12    48   M    169.8 75.40  14.7     94         149        51.4 24.7
# 13    23   M    180.1 65.90  14.4     72         130        45.4 18.1
# ...

# %%
summary(BP)
# Out:
#       나이       성별           키            몸무게          체지방률
#  Min.   :21.00   F:4926   Min.   :125.0   Min.   : 26.30   Min.   : 3.00
#  1st Qu.:25.00   M:8466   1st Qu.:162.4   1st Qu.: 58.20   1st Qu.:18.00
#  Median :32.00            Median :169.2   Median : 67.40   Median :22.80
#  Mean   :36.78            Mean   :168.6   Mean   : 67.45   Mean   :23.24
#  3rd Qu.:48.00            3rd Qu.:174.8   3rd Qu.: 75.30   3rd Qu.:28.00
#  Max.   :64.00            Max.   :193.8   Max.   :138.10   Max.   :54.90
#    이완기혈압      수축기혈압         악력        앞으로굽히기
#  Min.   :  0.0   Min.   :  0.0   Min.   : 0.00   Min.   :-18.40
#  1st Qu.: 71.0   1st Qu.:120.0   1st Qu.:27.50   1st Qu.: 10.90
#  Median : 79.0   Median :130.0   Median :37.90   Median : 16.20
#  Mean   : 78.8   Mean   :130.2   Mean   :36.96   Mean   : 15.23
#  3rd Qu.: 86.0   3rd Qu.:141.0   3rd Qu.:45.20   3rd Qu.: 20.70
#  Max.   :156.2   Max.   :201.0   Max.   :70.50   Max.   : 42.00
#   윗몸일으키기      멀리뛰기     등급          bmi
# ...

# %%
str(BP)
# Out:
# 'data.frame':	13392 obs. of  13 variables:
#  $ 나이        : int  27 25 31 32 28 36 42 33 54 28 ...
#  $ 성별        : Factor w/ 2 levels "F","M": 2 2 2 2 2 1 1 2 2 2 ...
#  $ 키          : num  172 165 180 174 174 ...
#  $ 몸무게      : num  75.2 55.8 78 71.1 67.7 ...
#  $ 체지방률    : num  21.3 15.7 20.1 18.4 17.1 22 32.2 36.9 27.6 14.4 ...
#  $ 이완기혈압  : num  80 77 92 76 70 64 72 84 85 81 ...
#  $ 수축기혈압  : num  130 126 152 147 127 119 135 137 165 156 ...
#  $ 악력        : num  54.9 36.4 44.8 41.4 43.5 23.8 22.7 45.9 40.4 57.9 ...
#  $ 앞으로굽히기: num  18.4 16.3 12 15.2 27.1 21 0.8 12.3 18.6 12.1 ...
#  $ 윗몸일으키기: num  60 53 49 53 45 27 18 42 34 55 ...
#  $ 멀리뛰기    : num  217 229 181 219 217 153 146 234 148 213 ...
#  $ 등급        : Factor w/ 4 levels "A","B","C","D": 3 1 3 2 2 2 4 2 3 2 ...
#  $ bmi         : num  25.3 20.5 24.2 23.3 22.4 20.3 23.5 25.2 24.3 24.7 ...

# %%
BP$성별 <- ifelse(BP$성별 == "M",1,2)

# %%
summary(BP)
# Out:
#       나이            성별             키            몸무게
#  Min.   :21.00   Min.   :1.000   Min.   :125.0   Min.   : 26.30
#  1st Qu.:25.00   1st Qu.:1.000   1st Qu.:162.4   1st Qu.: 58.20
#  Median :32.00   Median :1.000   Median :169.2   Median : 67.40
#  Mean   :36.78   Mean   :1.368   Mean   :168.6   Mean   : 67.45
#  3rd Qu.:48.00   3rd Qu.:2.000   3rd Qu.:174.8   3rd Qu.: 75.30
#  Max.   :64.00   Max.   :2.000   Max.   :193.8   Max.   :138.10
#     체지방률       이완기혈압      수축기혈압         악력
#  Min.   : 3.00   Min.   :  0.0   Min.   :  0.0   Min.   : 0.00
#  1st Qu.:18.00   1st Qu.: 71.0   1st Qu.:120.0   1st Qu.:27.50
#  Median :22.80   Median : 79.0   Median :130.0   Median :37.90
#  Mean   :23.24   Mean   : 78.8   Mean   :130.2   Mean   :36.96
#  3rd Qu.:28.00   3rd Qu.: 86.0   3rd Qu.:141.0   3rd Qu.:45.20
#  Max.   :54.90   Max.   :156.2   Max.   :201.0   Max.   :70.50
#   앞으로굽히기     윗몸일으키기      멀리뛰기     등급          bmi
# ...

# %%
str(BP)
# Out:
# 'data.frame':	13392 obs. of  13 variables:
#  $ 나이        : int  27 25 31 32 28 36 42 33 54 28 ...
#  $ 성별        : num  1 1 1 1 1 2 2 1 1 1 ...
#  $ 키          : num  172 165 180 174 174 ...
#  $ 몸무게      : num  75.2 55.8 78 71.1 67.7 ...
#  $ 체지방률    : num  21.3 15.7 20.1 18.4 17.1 22 32.2 36.9 27.6 14.4 ...
#  $ 이완기혈압  : num  80 77 92 76 70 64 72 84 85 81 ...
#  $ 수축기혈압  : num  130 126 152 147 127 119 135 137 165 156 ...
#  $ 악력        : num  54.9 36.4 44.8 41.4 43.5 23.8 22.7 45.9 40.4 57.9 ...
#  $ 앞으로굽히기: num  18.4 16.3 12 15.2 27.1 21 0.8 12.3 18.6 12.1 ...
#  $ 윗몸일으키기: num  60 53 49 53 45 27 18 42 34 55 ...
#  $ 멀리뛰기    : num  217 229 181 219 217 153 146 234 148 213 ...
#  $ 등급        : Factor w/ 4 levels "A","B","C","D": 3 1 3 2 2 2 4 2 3 2 ...
#  $ bmi         : num  25.3 20.5 24.2 23.3 22.4 20.3 23.5 25.2 24.3 24.7 ...

# %%
BP <- BP[,-c(6,7)]

# %%
str(BP)
summary(BP)
# Out:
# 'data.frame':	13392 obs. of  11 variables:
#  $ 나이        : int  27 25 31 32 28 36 42 33 54 28 ...
#  $ 성별        : num  1 1 1 1 1 2 2 1 1 1 ...
#  $ 키          : num  172 165 180 174 174 ...
#  $ 몸무게      : num  75.2 55.8 78 71.1 67.7 ...
#  $ 체지방률    : num  21.3 15.7 20.1 18.4 17.1 22 32.2 36.9 27.6 14.4 ...
#  $ 악력        : num  54.9 36.4 44.8 41.4 43.5 23.8 22.7 45.9 40.4 57.9 ...
#  $ 앞으로굽히기: num  18.4 16.3 12 15.2 27.1 21 0.8 12.3 18.6 12.1 ...
#  $ 윗몸일으키기: num  60 53 49 53 45 27 18 42 34 55 ...
#  $ 멀리뛰기    : num  217 229 181 219 217 153 146 234 148 213 ...
#  $ 등급        : Factor w/ 4 levels "A","B","C","D": 3 1 3 2 2 2 4 2 3 2 ...
#  $ bmi         : num  25.3 20.5 24.2 23.3 22.4 20.3 23.5 25.2 24.3 24.7 ...
#       나이            성별             키            몸무게
#  Min.   :21.00   Min.   :1.000   Min.   :125.0   Min.   : 26.30
#  1st Qu.:25.00   1st Qu.:1.000   1st Qu.:162.4   1st Qu.: 58.20
#  Median :32.00   Median :1.000   Median :169.2   Median : 67.40
# ...

# %%
boxplot(BP$나이)
# Out:
# plot without title

# %%
boxplot(BP$성별)
# Out:
# plot without title

# %%
boxplot(BP$키)
# Out:
# plot without title

# %%
boxplot(BP$몸무게)
# Out:
# plot without title

# %%
boxplot(BP$체지방률)
# Out:
# plot without title

# %%
boxplot(BP$악력)
# Out:
# plot without title

# %%
boxplot(BP$앞으로굽히기)
# Out:
# plot without title

# %%
boxplot(BP$멀리뛰기)
# Out:
# plot without title

# %%
boxplot(BP$bmi)
# Out:
# plot without title
